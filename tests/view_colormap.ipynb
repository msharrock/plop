# %%
import os
os.chdir('..')
import numpy as np
import matplotlib.pyplot as plt
import view

# %%
color_list = ['salmon', 'yellow', 'royalblue']
view.concentric_plot(color_list)

# %%
color_list = ['green', 'purple', 'orange']
view.concentric_plot(color_list)
